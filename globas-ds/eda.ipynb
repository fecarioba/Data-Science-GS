# %% [markdown]
# 🌍 Impactos das Queimadas na Saúde e no Meio AmbienteS

# %% [markdown]
# ## 👦 Integrantes:
#
# Djalma Andrade | RM555530
#
# Felipe Carioba | RM558447
#
# Lucas Henzo | RM554865
#
#
# ---

# %% [markdown]
# 📖 Contexto: As queimadas podem ser causadas por fatores naturais, como raios, ou humanos, como queimas mal controladas e até crimes. Com o aumento das temperaturas e secas prolongadas, esses incêndios têm se tornado mais frequentes e intensos, causando sérios impactos ambientais e à saúde pública.
#
# Eles destroem a vegetação, afetam a fauna e emitem grandes quantidades de fumaça e partículas tóxicas. Essas substâncias podem se espalhar por grandes distâncias, atingindo tanto áreas rurais quanto urbanas. Os principais efeitos na saúde incluem problemas respiratórios, cardiovasculares, impactos psicológicos e até deslocamento populacional.

# %% [markdown]
# ## **❓ Perguntas a serem investigadas**
#
# Existe tendência de aumento na duração dos incêndios ao longo dos anos?
#
# Queimadas de grande porte são mais frequentes em alguma época do ano?
#
# Qual é a distribuição geográfica das maiores queimadas (por latitude/longitude)?
#
# Estados com maior número de queimadas também concentram as maiores áreas queimadas?
#
# Existe alguma relação entre latitude/longitude e tipo de causa do incêndio?
#
# As causas humanas estão aumentando com o tempo?
#
# Há correlação entre o tempo de contenção (DISCOVERY_DATE - CONT_DATE) e o tamanho da queimada?
#
# Qual foi o maior incêndio registrado por área total?
#
# Existe alguma classe de tamanho que domina os registros?
#
# Incêndios de determinadas causas ocorrem mais em certos estados?

# %% [markdown]
# # 📊 Análise Quantitativa e Qualitativa das Variáveis - Dataset de Queimadas
#
# ---
#
# ### ✅ 1. `FOD_ID`
# - **Tipo**: Numérico (inteiro)
# - **Qualitativa**: Identificador único de cada registro de queimada.
# - **Quantitativa**: Usado para verificar duplicações e integridade da base.
#
# ---
#
# ### 🔥 2. `FIRE_NAME`
# - **Tipo**: Categórico (texto)
# - **Qualitativa**: Nome atribuído ao incêndio. Muitas vezes ausente ou genérico.
# - **Quantitativa**: Baixo valor analítico. Pode conter muitos valores nulos.
#
# ---
#
# ### 📅 3. `FIRE_YEAR`
# - **Tipo**: Numérico (inteiro)
# - **Qualitativa**: Ano de descoberta da queimada.
# - **Quantitativa**: Ideal para identificar tendências temporais (ex: aumento ao longo dos anos).
#
# ---
#
# ### 📆 4. `DISCOVERY_DATE`
# - **Tipo**: Temporal (data)
# - **Qualitativa**: Data exata de descoberta do incêndio.
# - **Quantitativa**: Permite análises mensais, semanais e sazonais.
#
# ---
#
# ### 📆 5. `DISCOVERY_DOY`
# - **Tipo**: Numérico (inteiro)
# - **Qualitativa**: Dia do ano em que a queimada foi descoberta.
# - **Quantitativa**: Útil para entender sazonalidade de forma direta.
#
# ---
#
# ### 🚨 6. `NWCG_CAUSE_CLASSIFICATION`
# - **Tipo**: Categórico (texto)
# - **Qualitativa**: Classificação da causa (Natural, Humana, etc).
# - **Quantitativa**: Essencial para entender a origem predominante dos incêndios.
#
# ---
#
# ### 💥 7. `NWCG_GENERAL_CAUSE`
# - **Tipo**: Categórico (texto)
# - **Qualitativa**: Causa específica (raio, acampamento, vandalismo, etc).
# - **Quantitativa**: Permite agrupamento e análise de recorrência de causas.
#
# ---
#
# ### 🧯 8. `CONT_DATE`
# - **Tipo**: Temporal (data)
# - **Qualitativa**: Data de controle/extinção do incêndio.
# - **Quantitativa**: Junto com a data de descoberta, permite calcular duração do incêndio.
#
# ---
#
# ### 🗓 9. `CONT_DOY`
# - **Tipo**: Numérico (inteiro)
# - **Qualitativa**: Dia do ano em que o incêndio foi contido.
# - **Quantitativa**: Usado para análises de tempo de resposta.
#
# ---
#
# ### 🌲 10. `FIRE_SIZE`
# - **Tipo**: Numérico contínuo (float)
# - **Qualitativa**: Área total queimada.
# - **Quantitativa**: Fundamental para medir severidade e comparar incêndios.
#
# ---
#
# ### 🅰️ 11. `FIRE_SIZE_CLASS`
# - **Tipo**: Categórico ordinal (A a G)
# - **Qualitativa**: Classificação do tamanho do incêndio (de A - pequeno até G - gigante).
# - **Quantitativa**: Boa para análises de frequência e impacto por região.
#
# ---
#
# ### 🌐 12. `LATITUDE` / 13. `LONGITUDE`
# - **Tipo**: Numérico (float)
# - **Qualitativa**: Localização do ponto de origem da queimada.
# - **Quantitativa**: Permite análises geoespaciais, mapas e clustering.
#
# ---
#
# ### 🏛 14. `STATE`
# - **Tipo**: Categórico (texto)
# - **Qualitativa**: Sigla do estado onde o incêndio ocorreu.
# - **Quantitativa**: Permite agrupamentos regionais, comparações entre estados e análises geográficas.
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(palette='bright')

# %%
df = pd.read_csv("wildfires.csv")
# Out:
# c:\AppData\Local\Temp\ipykernel_12780\1200285314.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("wildfires.csv")

# %%
df.head()
# Out:
#    FOD_ID FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_DOY  \
# 0       1  FOUNTAIN       2005       2/2/2005             33
# 1       2    PIGEON       2004      5/12/2004            133
# 2       3     SLACK       2004      5/31/2004            152
# 3       4      DEER       2004      6/28/2004            180
# 4       5  STEVENOT       2004      6/28/2004            180
#
#   NWCG_CAUSE_CLASSIFICATION                          NWCG_GENERAL_CAUSE  \
# 0                     Human  Power generation/transmission/distribution
# 1                   Natural                                     Natural
# 2                     Human                     Debris and open burning
# 3                   Natural                                     Natural
# 4                   Natural                                     Natural
#
#    CONT_DATE  CONT_DOY  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE STATE
# 0   2/2/2005      33.0       0.10               A  40.036944 -121.005833    CA
# ...

# %%
df.tail()
# Out:
#             FOD_ID        FIRE_NAME  FIRE_YEAR DISCOVERY_DATE  DISCOVERY_DOY  \
# 2303561  400732978            JONES       2020       6/5/2020            157
# 2303562  400732979            POWER       2020      7/11/2020            193
# 2303563  400732980          12 MILE       2020      8/27/2020            240
# 2303564  400732982      TAYLOR POND       2020      8/17/2020            230
# 2303565  400732984  MIDDLE MOUNTAIN       2020     11/20/2020            325
#
#                        NWCG_CAUSE_CLASSIFICATION  \
# 2303561                                  Natural
# 2303562  Missing data/not specified/undetermined
# 2303563                                  Natural
# 2303564                                  Natural
# 2303565                                    Human
#
#                               NWCG_GENERAL_CAUSE   CONT_DATE  CONT_DOY  \
# 2303561                                  Natural         NaN       NaN
# ...

# %%
df.describe()
# Out:
#              FOD_ID     FIRE_YEAR  DISCOVERY_DOY      CONT_DOY     FIRE_SIZE  \
# count  2.303566e+06  2.303566e+06   2.303566e+06  1.408753e+06  2.303566e+06
# mean   1.185100e+08  2.006167e+03   1.659714e+02  1.707579e+02  7.816088e+01
# std    1.621564e+08  8.044361e+00   8.975278e+01  8.626373e+01  2.630832e+03
# min    1.000000e+00  1.992000e+03   1.000000e+00  1.000000e+00  1.000000e-05
# 25%    6.225492e+05  2.000000e+03   9.100000e+01  9.900000e+01  1.000000e-01
# 50%    1.403630e+06  2.006000e+03   1.660000e+02  1.760000e+02  8.000000e-01
# 75%    3.000071e+08  2.013000e+03   2.310000e+02  2.320000e+02  3.000000e+00
# max    4.007330e+08  2.020000e+03   3.660000e+02  3.660000e+02  6.627000e+05
#
#            LATITUDE     LONGITUDE
# count  2.303566e+06  2.303566e+06
# mean   3.696623e+01 -9.635792e+01
# std    6.008260e+00  1.664360e+01
# min    1.793972e+01 -1.788026e+02
# 25%    3.301390e+01 -1.110361e+02
# 50%    3.572250e+01 -9.347009e+01
# ...

# %%
df.describe(exclude='number')
# Out:
#        FIRE_NAME DISCOVERY_DATE NWCG_CAUSE_CLASSIFICATION  \
# count    1308151        2303566                   2303566
# unique    701431          10593                         3
# top      UNKNOWN      2/10/2008                     Human
# freq       21356           1220                   1782906
#
#                              NWCG_GENERAL_CAUSE  CONT_DATE FIRE_SIZE_CLASS  \
# count                                   2303566    1408753         2303566
# unique                                       13      10596               7
# top     Missing data/not specified/undetermined  2/19/2011               B
# freq                                     597933        865         1104387
#
#           STATE
# count   2303566
# unique       52
# top          CA
# freq     251881

# %% [markdown]
# ## Análise Temporal das Queimadas: Frequência de Incêndios ao Longo dos Anos

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.countplot(x='FIRE_YEAR', data=df, palette='YlOrRd', ax=ax)
ax.set_title('Análise Temporal das Queimadas: Frequência de Incêndios ao Longo dos Anos')
ax.set_xlabel('Ano')
ax.set_ylabel('Número de Incêndios')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# c:\AppData\Local\Temp\ipykernel_12780\1880089642.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='FIRE_YEAR', data=df, palette='YlOrRd', ax=ax)

# %% [markdown]
# ## Evolução da Duração Média dos Incêndios ao Longo dos Anos

# %%
plt.figure(figsize=(10, 6))
line = sns.lineplot(x='FIRE_YEAR', y='DURACAO_INCENDIO', data=df, ci=None, marker='x', palette='Oranges')
plt.setp(line.lines, markersize=10)
plt.title('Evolução da Duração Média dos Incêndios ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Duração média (dias)')
plt.tight_layout()
plt.show()
# Out:
# c:\AppData\Local\Temp\ipykernel_12780\1782141643.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   line = sns.lineplot(x='FIRE_YEAR', y='DURACAO_INCENDIO', data=df, ci=None, marker='x', palette='Oranges')
# c:\AppData\Local\Temp\ipykernel_12780\1782141643.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   line = sns.lineplot(x='FIRE_YEAR', y='DURACAO_INCENDIO', data=df, ci=None, marker='x', palette='Oranges')

# %% [markdown]
# ## Distribuição das Queimadas por Mês e Classe de Tamanho

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='MONTH', hue='FIRE_SIZE_CLASS', data=df, order=range(1, 13), palette='Reds_r')
plt.title('Distribuição das Queimadas por Mês e Classe de Tamanho')
plt.xlabel('Mês')
plt.ylabel('Número de Incêndios')
plt.legend(title='Classe')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relação entre Frequência de Incêndios e Área Média Queimada por Estado

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='NUM_INCENDIOS', y='FIRE_SIZE', data=df_estado)
plt.title('Relação entre Frequência de Incêndios e Área Média Queimada por Estado')
plt.xlabel('Número de Incêndios')
plt.ylabel('Área Média Queimada')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 Causas Específicas de Queimadas

# %%
plt.figure(figsize=(12, 6))
top_causes = df['NWCG_GENERAL_CAUSE'].value_counts().head(10)
sns.barplot(x=top_causes.values, y=top_causes.index, palette='Reds_r')
plt.title('Top 10 Causas Específicas de Queimadas')
plt.xlabel('Número de Incêndios')
plt.ylabel('Causa Específica')
plt.tight_layout()
plt.show()
# Out:
# c:\AppData\Local\Temp\ipykernel_12780\3878223372.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_causes.values, y=top_causes.index, palette='Reds_r')

# %% [markdown]
# ## Evolução das Proporções de Causas de Queimadas por Ano

# %%
plt.figure(figsize=(15, 6))
causas_ano_prop.plot(kind='line', marker='o', colormap='inferno')
plt.title('Evolução das Proporções de Causas de Queimadas por Ano')
plt.ylabel('% por Causa')
plt.xlabel('Ano')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relação entre Duração do Incêndio e Tamanho da Queimada

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='DURACAO_INCENDIO', y='FIRE_SIZE', data=df, hue='DURACAO_INCENDIO', palette='coolwarm')
plt.title('Relação entre Duração do Incêndio e Tamanho da Queimada (Escala Logarítmica)')
plt.xlabel('Duração (dias)')
plt.ylabel('Área Queimada')
plt.yscale('log')
plt.tight_layout()
plt.show()
# Out:
# c:\AppData\Local\Temp\ipykernel_12780\3927693739.py:7: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# c:\Program Files\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
maior = df.loc[df['FIRE_SIZE'].idxmax()]
print(f"🔥 Maior incêndio registrado:\n\n"
      f"Nome: {maior['FIRE_NAME']}\n"
      f"Ano: {maior['FIRE_YEAR']}\n"
      f"Estado: {maior['STATE']}\n"
      f"Área: {maior['FIRE_SIZE']} acres\n"
      f"Causa: {maior['NWCG_GENERAL_CAUSE']}")
# Out:
# 🔥 Maior incêndio registrado:
#
# Nome: OKS - STARBUCK
# Ano: 2017
# Estado: OK
# Área: 662700.0 acres
# Causa: Missing data/not specified/undetermined

# %% [markdown]
# ## Causa Mais Comum de Queimadas por Estado

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='STATE', y='count', hue='NWCG_GENERAL_CAUSE', data=causa_estado, palette='Reds_r')
plt.title('Causa Mais Comum de Queimadas por Estado')
plt.xlabel('Estado')
plt.ylabel('Número de Incêndios')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
